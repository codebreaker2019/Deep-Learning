# %%
Dictionary = {
"ApplyEyeMakeup":0,
"ApplyLipstick":1,
"Archery":2,
"BabyCrawling":3,
"BalanceBeam":4,
"BandMarching":5,
"BaseballPitch":6,
"Basketball":7,
"BasketballDunk":8,
"BenchPress":9,
"Biking":10,
"Billiards":11,
"BlowDryHair":12,
"BlowingCandles":13,
"BodyWeightSquats":14,
"BoxingPunchingBag":15,
"BoxingSpeedBag":16,
"BreastStroke":17,
"BrushingTeeth":18,
"CleanAndJerk":19,
"CliffDiving":20,
"CricketBowling":21,
"CricketShot":22,
"CuttingInKitchen":23,
"Drumming":24,
"Fencing":25

}

# %%
print(Dictionary
     )
# Out:
# {'ApplyEyeMakeup': 0, 'ApplyLipstick': 1, 'Archery': 2, 'BabyCrawling': 3, 'BalanceBeam': 4, 'BandMarching': 5, 'BaseballPitch': 6, 'Basketball': 7, 'BasketballDunk': 8, 'BenchPress': 9, 'Biking': 10, 'Billiards': 11, 'BlowDryHair': 12, 'BlowingCandles': 13, 'BodyWeightSquats': 14, 'BoxingPunchingBag': 15, 'BoxingSpeedBag': 16, 'BreastStroke': 17, 'BrushingTeeth': 18, 'CleanAndJerk': 19, 'CliffDiving': 20, 'CricketBowling': 21, 'CricketShot': 22, 'CuttingInKitchen': 23, 'Drumming': 24, 'Fencing': 25}

# %% [markdown]
# diction = {
# 0:'ApplyEyeMakeup',
# 1:'ApplyLipstick',
# 2:'Archery',
# 3:'BabyCrawling',
# 4:'BalanceBeam',
# 5:'BandMarching',
# 6:'BaseballPitch',
# 7:'Basketball',
# 8:'BasketballDunk',
# 9:'BenchPress',
# 10:'Biking',
# 11:'Billiards',
# 12:'BlowDryHair',
# 13:'BlowingCandles',
# 14:'BodyWeightSquats',
# 15:'BoxingPunchingBag',
# 16:'BoxingSpeedBag',
# 17:'BreastStroke',
# 18:'BrushingTeeth',
# 19:'CleanAndJerk',
# 20:'CliffDiving',
# 21:'CricketShot',
# 22:'CuttingInKitchen',
# 23:'Drumming',
# 24:'Fencing',
# 25:'FieldHockeyPenalty',
# 26:'FloorGymnastics',
# 27:'FrisbeeCatch',
# 28:'FrontCrawl',
# 29:'GolfSwing',
# 30:'Haircut',
# 31:'HammeringHammering',
# 32:'HammerThrow',
# 33:'HandstandWalking',
# 34:'HeadMassage',
# 35:'HighJump',
# 36:'HorseRace',
# 37:'HorseRiding',
# 38:'HulaHoop',
# 39:'IceDancing',
# 40:'JavelinThrow',
# 41:'JugglingJack',
# 42:'JumpingJack',
# 43:'JumpRope',
# 44:'Kayaking',
# 45:'Knitting',
# 46:'LongJump',
# 47:'Lunges',
# 48:'MilitaryParade',
# 49:'Mixing',
# 50:'MoppingFloor',
# 51:'Nunchucks',
# 52:'ParallelBars',
# 53:'PizzaTossing',
# 54:'PlayingCello',
# 55:'PlayingDaf',
# 56:'PlayingDhol',
# 57:'PlayingFlute',
# 58:'PlayingGuitar',
# 59:'PlayingPiano',
# 60:'PlayingSitar',
# 61:'PlayingTabla',
# 62:'PlayingViolin',
# 63:'PoleVault',
# 64:'PommelHorse',
# 65:'PullUps',
# 66:'Punch',
# 67:'PushUps',
# 68:'Rafting'
# }

# %%
diction = {
"ApplyEyeMakeup":0,
"ApplyLipstick":1,
"Archery":2,
"BabyCrawling":3,
"BalanceBeam":4,
"BandMarching":5,
"BaseballPitch":6,
"Basketball":7,
"BasketballDunk":8,
"BenchPress":9, 
"Biking":10, 
"Billiards":11,
"BlowDryHair":12,
"BlowingCandles":13, 
"BodyWeightSquats":14,
"BoxingPunchingBag":15,
"BoxingSpeedBag":16,
"BreastStroke":17,
"BrushingTeeth":18, 
"CleanAndJerk":19,
"CliffDiving":20, 
"CricketBowling":21,
"CricketShot":22,
"CuttingInKitchen":23, 
"Drumming":24,
"Fencing":25, 
"FieldHockeyPenalty":26, 
"FloorGymnastics":27, 
"FrisbeeCatch":28,
"FrontCrawl":29, 
"GolfSwing":30, 
"Haircut":31, 
"HammeringHammering":32,
"HammerThrow":33, 
"HandstandPushups":34,
"HandstandWalking":35, 
"HeadMassag3e":36, 
"HighJump":37, 
"HorseRace":38, 
"HorseRiding":39, 
"HulaHoop":40,
"IceDancing":41, 
"JavelinThrow":42,
"JugglingBalls":43, 
"JumpingJack":44,
"JumpRope":45,
"Kayaking":46, 
"Knitting":47, 
"LongJump":48, 
"Lunges":49, 
"MilitaryParade":50,
"Mixing":51, 
"MoppingFloor":52, 
"Nunchucks":53, 
"ParallelBars":54, 
"PizzaTossing":55, 
"PlayingCello":56,
"PlayingDaf":57,
"PlayingDhol":58,
"PlayingFlute":59,
"PlayingGuitar":60, 
"PlayingPiano":61,
"PlayingSitar":62, 
"PlayingTabla":63, 
"PlayingViolin":64, 
"PoleVault":65, 
"PommelHorse":66,
"PullUps":67,
"Punch":68, 
"PushUps":69,
"Rafting":70 
}

# %%
print(diction)
# Out:
# {'ApplyEyeMakeup': 0, 'ApplyLipstick': 1, 'Archery': 2, 'BabyCrawling': 3, 'BalanceBeam': 4, 'BandMarching': 5, 'BaseballPitch': 6, 'Basketball': 7, 'BasketballDunk': 8, 'BenchPress': 9, 'Biking': 10, 'Billiards': 11, 'BlowDryHair': 12, 'BlowingCandles': 13, 'BodyWeightSquats': 14, 'BoxingPunchingBag': 15, 'BoxingSpeedBag': 16, 'BreastStroke': 17, 'BrushingTeeth': 18, 'CleanAndJerk': 19, 'CliffDiving': 20, 'CricketBowling': 21, 'CricketShot': 22, 'CuttingInKitchen': 23, 'Drumming': 24, 'Fencing': 25, 'FieldHockeyPenalty': 26, 'FloorGymnastics': 27, 'FrisbeeCatch': 28, 'FrontCrawl': 29, 'GolfSwing': 30, 'Haircut': 31, 'HammeringHammering': 32, 'HammerThrow': 33, 'HandstandPushups': 34, 'HandstandWalking': 35, 'HeadMassag3e': 36, 'HighJump': 37, 'HorseRace': 38, 'HorseRiding': 39, 'HulaHoop': 40, 'IceDancing': 41, 'JavelinThrow': 42, 'JugglingBalls': 43, 'JumpingJack': 44, 'JumpRope': 45, 'Kayaking': 46, 'Knitting': 47, 'LongJump': 48, 'Lunges': 49, 'MilitaryParade': 50, 'Mixing': 51, 
# ...
